# %% [markdown]
# # Vision Tagging — Bharani's Retail & Co.
# AI-900 domain: Computer vision workloads
#
# Uses Azure AI Vision to tag, caption, and detect objects in synthetic product photos.

# %% [markdown]
# ## 1. Setup
# Load credentials from `.env` (never hardcode keys).

# %%
from dotenv import load_dotenv
import os

load_dotenv()
VISION_ENDPOINT = os.getenv("AZURE_VISION_ENDPOINT")
VISION_KEY = os.getenv("AZURE_VISION_KEY")

# %% [markdown]
# ## 2. Load sample product images
# Point this at a local `images/` folder with a few synthetic product photos.

# %%
import glob

image_paths = glob.glob("images/*.jpg")
image_paths

# %% [markdown]
# ## 3. Call Azure AI Vision — Tags + Caption
# Reference: https://learn.microsoft.com/azure/ai-services/computer-vision/

# %%
# from azure.ai.vision.imageanalysis import ImageAnalysisClient
# from azure.core.credentials import AzureKeyCredential
#
# client = ImageAnalysisClient(endpoint=VISION_ENDPOINT, credential=AzureKeyCredential(VISION_KEY))
#
# for path in image_paths:
#     with open(path, "rb") as f:
#         result = client.analyze(image_data=f.read(), visual_features=["Tags", "Caption"])
#     print(path, result.caption.text, result.tags)

# %% [markdown]
# ## 4. Results table
# Summarize tags, captions, confidence scores per image.

# %%
import pandas as pd

# results_df = pd.DataFrame(...)
# results_df

# %% [markdown]
# ## 5. Notes
# What surprised me, what the confidence scores looked like, anything that maps back to an exam objective.
